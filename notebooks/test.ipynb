# %%
import pandas as pd
import dask.dataframe as dd
path='C:/Users/Sarv/Desktop/vs_code/Git/ETL-pipeline/data/raw/trade_history_table.h5'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Sarv\Desktop\vs_code\Git\ETL-pipeline\notebooks\test.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Sarv/Desktop/vs_code/Git/ETL-pipeline/notebooks/test.ipynb#ch0000000?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sarv/Desktop/vs_code/Git/ETL-pipeline/notebooks/test.ipynb#ch0000000?line=1'>2</a> import dask.dataframe as dd
#       <a href='vscode-notebook-cell:/c%3A/Users/Sarv/Desktop/vs_code/Git/ETL-pipeline/notebooks/test.ipynb#ch0000000?line=2'>3</a> path='C:/Users/Sarv/Desktop/vs_code/Git/ETL-pipeline/data/raw/trade_history_table.h5'
#
# ModuleNotFoundError: No module named 'dask'

# %%
pd.read_hdf(path)
# Out:
#       insCode dEven nTran   hEven qTitTran   pTran qTitNgJ iSensVarP  \
# 0         NaN     0   511  130534     3000  3100.0       0       NaN
# 1         NaN     0   629  111514    10939  3100.0       0       NaN
# 2         NaN     0   625  111513    25000  3100.0       0       NaN
# 3         NaN     0   623  111512      500  3100.0       0       NaN
# 4         NaN     0   619  111511    35000  3100.0       0       NaN
# ...       ...   ...   ...     ...      ...     ...     ...       ...
# 20177     NaN     0   101  121953   100000  4100.0       0       NaN
# 20178     NaN     0     1   90425     4000  4300.0       0       NaN
# 20179     NaN     0     2  113635     1000  4300.0       0       NaN
# 20180     NaN     0     1   90547    10000  4300.0       0       NaN
# 20181     NaN     0   280  112722    45820  4100.0       0       NaN
#
#       pPhSeaCotJ pPbSeaCotJ iAnuTran xqVarPJDrPRf canceledCompony  \
# 0            0.0        0.0        0          0.0             NaN
# ...
